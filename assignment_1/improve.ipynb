# %%
# Full improved training code using PyTorch with best practices for binary classification

import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE
import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F

# Load and preprocess the dataset
df = pd.read_csv("dataset.csv")
df.drop(columns=["Id"], inplace=True)

# Replace zeros with NaN in key columns
fields_with_invalid_zeros = ['Glucose', 'BloodPressure', 'SkinThickness', 'Insulin', 'BMI']
for col in fields_with_invalid_zeros:
    df[col] = df[col].apply(lambda x: np.nan if x == 0 else x)

# Impute missing values using median
imputer = SimpleImputer(strategy='median')
df_imputed = pd.DataFrame(imputer.fit_transform(df), columns=df.columns)

# Split features and labels
X = df_imputed.drop(columns=['Outcome'])
y = df_imputed['Outcome']

# Normalize features
scaler = StandardScaler()
X_scaled = pd.DataFrame(scaler.fit_transform(X), columns=X.columns)

# Train-test split BEFORE SMOTE to avoid data leakage
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# Apply SMOTE only to training data
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Combine resampled data into DataFrame
train_df = pd.DataFrame(X_train_resampled, columns=X.columns)
train_df['Outcome'] = y_train_resampled.values

test_df = pd.DataFrame(X_test, columns=X.columns)
test_df['Outcome'] = y_test.values

# Define custom dataset class
class CustomDataset(Dataset):
    def __init__(self, dataframe):
        self.data = dataframe

    def __len__(self):
        return len(self.data)

    def __getitem__(self, index):
        row = self.data.iloc[index]
        features = torch.tensor(row[:-1].values, dtype=torch.float32)
        label = torch.tensor(row[-1], dtype=torch.float32).unsqueeze(0)
        return features, label

# Define the neural network (no sigmoid at the end)
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(8, 32),
            nn.ReLU(),
            nn.Linear(32, 16),
            nn.ReLU(),
            nn.Linear(16, 1)  # No Sigmoid here
        )

    def forward(self, x):
        return self.model(x)

# Training and testing functions
def train(data_loader, model, loss_fn, optimizer, device):
    model.train()
    for X, y in data_loader:
        X, y = X.to(device), y.to(device)
        pred = model(X)
        loss = loss_fn(pred, y)
        loss.backward()
        optimizer.step()
        optimizer.zero_grad()

def test(data_loader, model, loss_fn, device):
    model.eval()
    total_loss = 0
    correct = 0
    size = len(data_loader.dataset)

    with torch.no_grad():
        for X, y in data_loader:
            X, y = X.to(device), y.to(device)
            pred = model(X)
            pred_prob = torch.sigmoid(pred)  # For accuracy calculation
            predicted = (pred_prob >= 0.5).float()
            total_loss += loss_fn(pred, y).item()
            correct += (predicted == y).sum().item()

    accuracy = correct / size
    print(f"Test Accuracy: {accuracy:.4f}, Avg Loss: {total_loss / len(data_loader):.6f}")

# Prepare DataLoaders
train_dataset = CustomDataset(train_df)
test_dataset = CustomDataset(test_df)
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=64, shuffle=False)

# Initialize model, optimizer, and loss function
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = NeuralNetwork().to(device)
loss_fn = nn.BCEWithLogitsLoss()  # Use BCEWithLogitsLoss for logits output
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Training loop
epochs = 200
for epoch in range(epochs):
    print(f"Epoch {epoch + 1}")
    train(train_loader, model, loss_fn, optimizer, device)
    test(test_loader, model, loss_fn, device)
print("Training complete.")
# Out:
# Epoch 1
# Test Accuracy: 0.7635, Avg Loss: 0.621034
# Epoch 2
# Test Accuracy: 0.7491, Avg Loss: 0.542599
# Epoch 3
# /var/folders/7y/tb8vlfv937523rgqdlf0zjy40000gn/T/ipykernel_99803/797720714.py:60: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   label = torch.tensor(row[-1], dtype=torch.float32).unsqueeze(0)
# Test Accuracy: 0.7581, Avg Loss: 0.480487
# Epoch 4
# Test Accuracy: 0.7834, Avg Loss: 0.477858
# Epoch 5
# Test Accuracy: 0.7816, Avg Loss: 0.464499
# Epoch 6
# Test Accuracy: 0.7888, Avg Loss: 0.461093
# Epoch 7
# Test Accuracy: 0.7888, Avg Loss: 0.447925
# Epoch 8
# Test Accuracy: 0.7870, Avg Loss: 0.450978
# Epoch 9
# Test Accuracy: 0.7834, Avg Loss: 0.456832
# Epoch 10
# Test Accuracy: 0.7888, Avg Loss: 0.444314
# Epoch 11
# Test Accuracy: 0.7852, Avg Loss: 0.439645
# Epoch 12
# Test Accuracy: 0.7870, Avg Loss: 0.444747
# Epoch 13
# Test Accuracy: 0.7834, Avg Loss: 0.437236
# Epoch 14
# Test Accuracy: 0.7924, Avg Loss: 0.431001
# Epoch 15
# Test Accuracy: 0.7960, Avg Loss: 0.436724
# Epoch 16
# Test Accuracy: 0.8051, Avg Loss: 0.424957
# Epoch 17
# Test Accuracy: 0.8375, Avg Loss: 0.339636
# Epoch 64
# Test Accuracy: 0.8357, Avg Loss: 0.341477
# Epoch 65
# Test Accuracy: 0.8412, Avg Loss: 0.341136
# Epoch 66
# Test Accuracy: 0.8466, Avg Loss: 0.335025
# Epoch 67
# Test Accuracy: 0.8484, Avg Loss: 0.331751
# Epoch 68
# Test Accuracy: 0.8394, Avg Loss: 0.337426
# Epoch 69
# Test Accuracy: 0.8375, Avg Loss: 0.333795
# Epoch 70
# Test Accuracy: 0.8394, Avg Loss: 0.334927
# Epoch 71
# Test Accuracy: 0.8394, Avg Loss: 0.333600
# Epoch 72
# Test Accuracy: 0.8321, Avg Loss: 0.338513
# Epoch 73
# Test Accuracy: 0.8394, Avg Loss: 0.328678
# Epoch 74
# Test Accuracy: 0.8412, Avg Loss: 0.327014
# Epoch 75
# Test Accuracy: 0.8412, Avg Loss: 0.325204
# Epoch 76
# Test Accuracy: 0.8448, Avg Loss: 0.330705
# Epoch 77
# Test Accuracy: 0.8412, Avg Loss: 0.328176
# Epoch 78
# Test Accuracy: 0.8357, Avg Loss: 0.320982
# Epoch 79
# Test Accuracy: 0.8412, Avg Loss: 0.321699
# Epoch 80
# Test Accuracy: 0.8412, Avg Loss: 0.326085
# Epoch 81
# Test Accuracy: 0.8484, Avg Loss: 0.325973
# Epoch 82
# Test Accuracy: 0.8394, Avg Loss: 0.318473
# Epoch 83
# Test Accuracy: 0.8448, Avg Loss: 0.326046
# Epoch 84
# Test Accuracy: 0.8520, Avg Loss: 0.318808
# Epoch 85
# Test Accuracy: 0.8538, Avg Loss: 0.318163
# Epoch 86
# Test Accuracy: 0.8375, Avg Loss: 0.326950
# Epoch 87
# Test Accuracy: 0.8394, Avg Loss: 0.324506
# Epoch 88
# Test Accuracy: 0.8484, Avg Loss: 0.313780
# Epoch 89
# Test Accuracy: 0.8520, Avg Loss: 0.321046
# Epoch 90
# Test Accuracy: 0.8502, Avg Loss: 0.315805
# Epoch 91
# Test Accuracy: 0.8484, Avg Loss: 0.320192
# Epoch 92
# Test Accuracy: 0.8466, Avg Loss: 0.312022
# Epoch 93
# Test Accuracy: 0.8394, Avg Loss: 0.316863
# Epoch 94
# Test Accuracy: 0.8502, Avg Loss: 0.306231
# Epoch 95
# Test Accuracy: 0.8502, Avg Loss: 0.323094
# Epoch 96
# Test Accuracy: 0.8484, Avg Loss: 0.310430
# Epoch 97
# Test Accuracy: 0.8610, Avg Loss: 0.318624
# Epoch 98
# Test Accuracy: 0.8538, Avg Loss: 0.310700
# Epoch 99
# Test Accuracy: 0.8592, Avg Loss: 0.311171
# Epoch 100
# Test Accuracy: 0.8466, Avg Loss: 0.300786
# Epoch 101
# Test Accuracy: 0.8538, Avg Loss: 0.313984
# Epoch 102
# Test Accuracy: 0.8448, Avg Loss: 0.309344
# Epoch 103
# Test Accuracy: 0.8448, Avg Loss: 0.312922
# Epoch 104
# Test Accuracy: 0.8484, Avg Loss: 0.302823
# Epoch 105
# Test Accuracy: 0.8484, Avg Loss: 0.303800
# Epoch 106
# Test Accuracy: 0.8484, Avg Loss: 0.305996
# Epoch 107
# Test Accuracy: 0.8484, Avg Loss: 0.309547
# Epoch 108
# Test Accuracy: 0.8502, Avg Loss: 0.301544
# Epoch 109
# Test Accuracy: 0.8484, Avg Loss: 0.301786
# Epoch 110
# Test Accuracy: 0.8610, Avg Loss: 0.309407
# Epoch 111
# Test Accuracy: 0.8430, Avg Loss: 0.300481
# Epoch 112
# Test Accuracy: 0.8610, Avg Loss: 0.311511
# Epoch 113
# Test Accuracy: 0.8610, Avg Loss: 0.309104
# Epoch 114
# Test Accuracy: 0.8610, Avg Loss: 0.310754
# Epoch 115
# Test Accuracy: 0.8592, Avg Loss: 0.305312
# Epoch 116
# Test Accuracy: 0.8646, Avg Loss: 0.297151
# Epoch 117
# Test Accuracy: 0.8664, Avg Loss: 0.297017
# Epoch 118
# Test Accuracy: 0.8610, Avg Loss: 0.296088
# Epoch 119
# Test Accuracy: 0.8628, Avg Loss: 0.299457
# Epoch 120
# Test Accuracy: 0.8538, Avg Loss: 0.298366
# Epoch 121
# Test Accuracy: 0.8682, Avg Loss: 0.295881
# Epoch 122
# Test Accuracy: 0.8592, Avg Loss: 0.305687
# Epoch 123
# Test Accuracy: 0.8610, Avg Loss: 0.297240
# Epoch 124
# Test Accuracy: 0.8610, Avg Loss: 0.297240
# Epoch 125
# Test Accuracy: 0.8646, Avg Loss: 0.294747
# Epoch 126
# Test Accuracy: 0.8700, Avg Loss: 0.296666
# Epoch 127
# Test Accuracy: 0.8628, Avg Loss: 0.300571
# Epoch 128
# Test Accuracy: 0.8700, Avg Loss: 0.302422
# Epoch 129
# Test Accuracy: 0.8682, Avg Loss: 0.294669
# Epoch 130
# Test Accuracy: 0.8682, Avg Loss: 0.303339
# Epoch 131
# Test Accuracy: 0.8736, Avg Loss: 0.299996
# Epoch 132
# Test Accuracy: 0.8682, Avg Loss: 0.299208
# Epoch 133
# Test Accuracy: 0.8773, Avg Loss: 0.290719
# Epoch 134
# Test Accuracy: 0.8755, Avg Loss: 0.294325
# Epoch 135
# Test Accuracy: 0.8682, Avg Loss: 0.292622
# Epoch 136
# Test Accuracy: 0.8809, Avg Loss: 0.285968
# Epoch 137
# Test Accuracy: 0.8791, Avg Loss: 0.286097
# Epoch 138
# Test Accuracy: 0.8736, Avg Loss: 0.292117
# Epoch 139
# Test Accuracy: 0.8773, Avg Loss: 0.294076
# Epoch 140
# Test Accuracy: 0.8755, Avg Loss: 0.288927
# Epoch 141
# Test Accuracy: 0.8755, Avg Loss: 0.281759
# Epoch 142
# Test Accuracy: 0.8791, Avg Loss: 0.291530
# Epoch 143
# Test Accuracy: 0.8791, Avg Loss: 0.280190
# Epoch 144
# Test Accuracy: 0.8773, Avg Loss: 0.284938
# Epoch 145
# Test Accuracy: 0.8827, Avg Loss: 0.292290
# Epoch 146
# Test Accuracy: 0.8791, Avg Loss: 0.291182
# Epoch 147
# Test Accuracy: 0.8845, Avg Loss: 0.287576
# Epoch 148
# Test Accuracy: 0.8736, Avg Loss: 0.291835
# Epoch 149
# Test Accuracy: 0.8736, Avg Loss: 0.285797
# Epoch 150
# Test Accuracy: 0.8755, Avg Loss: 0.293066
# Epoch 151
# Test Accuracy: 0.8953, Avg Loss: 0.276705
# Epoch 152
# Test Accuracy: 0.8791, Avg Loss: 0.294453
# Epoch 153
# Test Accuracy: 0.8845, Avg Loss: 0.284515
# Epoch 154
# Test Accuracy: 0.8917, Avg Loss: 0.283966
# Epoch 155
# Test Accuracy: 0.8845, Avg Loss: 0.279950
# Epoch 156
# Test Accuracy: 0.8809, Avg Loss: 0.285710
# Epoch 157
# Test Accuracy: 0.8809, Avg Loss: 0.276984
# Epoch 158
# Test Accuracy: 0.8755, Avg Loss: 0.288021
# Epoch 159
# Test Accuracy: 0.8899, Avg Loss: 0.282388
# Epoch 160
# Test Accuracy: 0.8755, Avg Loss: 0.282036
# Epoch 161
# Test Accuracy: 0.8881, Avg Loss: 0.273134
# Epoch 162
# Test Accuracy: 0.8953, Avg Loss: 0.271430
# Epoch 163
# Test Accuracy: 0.8863, Avg Loss: 0.279642
# Epoch 164
# Test Accuracy: 0.8700, Avg Loss: 0.288281
# Epoch 165
# Test Accuracy: 0.8971, Avg Loss: 0.270413
# Epoch 166
# Test Accuracy: 0.8845, Avg Loss: 0.287837
# Epoch 167
# Test Accuracy: 0.8917, Avg Loss: 0.271563
# Epoch 168
# Test Accuracy: 0.8700, Avg Loss: 0.284772
# Epoch 169
# Test Accuracy: 0.8755, Avg Loss: 0.274059
# Epoch 170
# Test Accuracy: 0.8899, Avg Loss: 0.274975
# Epoch 171
# Test Accuracy: 0.8935, Avg Loss: 0.271629
# Epoch 172
# Test Accuracy: 0.8773, Avg Loss: 0.281845
# Epoch 173
# Test Accuracy: 0.8881, Avg Loss: 0.278413
# Epoch 174
# Test Accuracy: 0.8881, Avg Loss: 0.275427
# Epoch 175
# Test Accuracy: 0.8953, Avg Loss: 0.269037
# Epoch 176
# Test Accuracy: 0.9043, Avg Loss: 0.269132
# Epoch 177
# Test Accuracy: 0.8971, Avg Loss: 0.274965
# Epoch 178
# Test Accuracy: 0.8845, Avg Loss: 0.276484
# Epoch 179
# Test Accuracy: 0.8863, Avg Loss: 0.275293
# Epoch 180
# Test Accuracy: 0.8773, Avg Loss: 0.284562
# Epoch 181
# Test Accuracy: 0.8881, Avg Loss: 0.271550
# Epoch 182
# Test Accuracy: 0.8773, Avg Loss: 0.292033
# Epoch 183
# Test Accuracy: 0.8917, Avg Loss: 0.272798
# Epoch 184
# Test Accuracy: 0.8953, Avg Loss: 0.270399
# Epoch 185
# Test Accuracy: 0.8809, Avg Loss: 0.274351
# Epoch 186
# Test Accuracy: 0.8773, Avg Loss: 0.294289
# Epoch 187
# Test Accuracy: 0.8989, Avg Loss: 0.267839
# Epoch 188
# Test Accuracy: 0.8953, Avg Loss: 0.270715
# Epoch 189
# Test Accuracy: 0.8935, Avg Loss: 0.273933
# Epoch 190
# Test Accuracy: 0.9025, Avg Loss: 0.271494
# Epoch 191
# Test Accuracy: 0.8989, Avg Loss: 0.272162
# Epoch 192
# Test Accuracy: 0.9061, Avg Loss: 0.265187
# Epoch 193
# Test Accuracy: 0.9061, Avg Loss: 0.267081
# Epoch 194
# Test Accuracy: 0.9025, Avg Loss: 0.269550
# Epoch 195
# Test Accuracy: 0.9061, Avg Loss: 0.264818
# Epoch 196
# Test Accuracy: 0.8881, Avg Loss: 0.280193
# Epoch 197
# Test Accuracy: 0.9097, Avg Loss: 0.263630
# Epoch 198
# Test Accuracy: 0.9116, Avg Loss: 0.266353
# Epoch 199
# Test Accuracy: 0.9116, Avg Loss: 0.262365
# Epoch 200
# Test Accuracy: 0.9097, Avg Loss: 0.263790
# Training complete.
